# %%
import pandas as pd

# %%
dt= pd.read_csv('abandono.csv')

# %%
dt.head()
# Out:
#        Marca temporal                           Consentimiento informado  \
# 0   24/9/2025 0:34:33  He leído y acepto participar de forma voluntar...
# 1  23/9/2025 19:05:37  He leído y acepto participar de forma voluntar...
# 2  23/9/2025 19:05:59  He leído y acepto participar de forma voluntar...
# 3  23/9/2025 19:06:15  He leído y acepto participar de forma voluntar...
# 4  23/9/2025 19:06:32  He leído y acepto participar de forma voluntar...
#
#   Indica tu rango de edad  Cuál es tu genero  \
# 0               20–22 años          Femenino
# 1               23–25 años          Femenino
# 2               23–25 años          Femenino
# 3                Más de 30          Femenino
# 4               17–19 años          Femenino
#
#   Semestre en el que te encuentras actualmente  \
# 0                                           1°
# 1                                           3°
# 2                                           3°
# 3                                           6°
# ...

# %%
dt.isnull().sum()
# Out:
# Marca temporal                                                                                 0
# Consentimiento informado                                                                       0
# Indica tu rango de edad                                                                        0
# Cuál es tu genero                                                                              0
# Semestre en el que te encuentras actualmente                                                   0
# Carrera o programa académico                                                                   0
# ¿Has pensado en abandonar la universidad en algún momento?                                     0
# Si respondiste “sí” en la anterior, ¿Cuál fue la razón principal?                             31
# ¿Cuentas con algún tipo de beca o apoyo institucional?                                         0
# ¿Cómo calificas tu nivel de estrés relacionado con los estudios?                               0
# ...

# %%
dt['Si respondiste “sí”, ¿Cuál fue la razón principal por la que abandonó?'] = dt['Si respondiste “sí”, ¿Cuál fue la razón principal por la que abandonó?'].fillna('Económica')

# %%
dt.isnull().sum()
# Out:
# Marca temporal                                                                                0
# Consentimiento informado                                                                      0
# Indica tu rango de edad                                                                       0
# Cuál es tu genero                                                                             0
# Semestre en el que te encuentras actualmente                                                  0
# Carrera o programa académico                                                                  0
# ¿Has pensado en abandonar la universidad en algún momento?                                    0
# Si respondiste “sí” en la anterior, ¿Cuál fue la razón principal?                             0
# ¿Cuentas con algún tipo de beca o apoyo institucional?                                        0
# ¿Cómo calificas tu nivel de estrés relacionado con los estudios?                              0
# ...

# %%
dt.head()
# Out:
#        Marca temporal                           Consentimiento informado  \
# 0   24/9/2025 0:34:33  He leído y acepto participar de forma voluntar...
# 1  23/9/2025 19:05:37  He leído y acepto participar de forma voluntar...
# 2  23/9/2025 19:05:59  He leído y acepto participar de forma voluntar...
# 3  23/9/2025 19:06:15  He leído y acepto participar de forma voluntar...
# 4  23/9/2025 19:06:32  He leído y acepto participar de forma voluntar...
#
#   Indica tu rango de edad  Cuál es tu genero  \
# 0               20–22 años          Femenino
# 1               23–25 años          Femenino
# 2               23–25 años          Femenino
# 3                Más de 30          Femenino
# 4               17–19 años          Femenino
#
#   Semestre en el que te encuentras actualmente  \
# 0                                           1°
# 1                                           3°
# 2                                           3°
# 3                                           6°
# ...

# %%
df= dt[['¿Qué sugerencias darías para reducir el abandono escolar en tu salón o en la universidad?']]

# %%
df
# Out:
#     ¿Qué sugerencias darías para reducir el abandono escolar en tu salón o en la universidad?
# 0    Para los que trabajamos tener algún apoyo a es...
# 1    Las pláticas hacia los estudiantes para conoce...
# 2    Considero que pudiera ayudar la accesibilidad ...
# 3    Becas en efectivo o con apoyo de dispositivos,...
# 4    Más comprensión y flexibilidad de parte de doc...
# ..                                                 ...
# 179  Interes real en apoyar la salud mental y emoci...
# 180                                                  -
# 181  Mas apoyo a las personas que ya no continuan, ...
# 182                         Asignaturas no esenciales
# 183  Algún apoyo para los que estamos distancia ya ...
#
# [184 rows x 1 columns]
